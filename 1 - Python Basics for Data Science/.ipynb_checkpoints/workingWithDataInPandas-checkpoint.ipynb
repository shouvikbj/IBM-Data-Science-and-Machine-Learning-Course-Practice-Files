# %%
# Loading data with "pandas" library
import pandas as pd

csv_path = 'data.csv'
df = pd.read_csv(csv_path)
df.head()
# Out:
#                name  age    sex  \
# 0  Shouvik Bajpayee   22   Male
# 1  Shouvik Bajpayee   22   Male
# 2  Shouvik Bajpayee   18  Other
# 3  Shouvik Bajpayee   87    NaN
# 4  SHOUVIK BAJPAYEE   23   Male
#
#                                              address       phone  \
# 0  Kanakpur, Panskura (R.S.), Purba Medinipur, 72...  9734282057
# 1             KANAKPUR,PANSKURA R.S.,PURBA MEDINIPUR  9734282057
# 2             KANAKPUR,PANSKURA R.S.,PURBA MEDINIPUR  8617623168
# 3             KANAKPUR,PANSKURA R.S.,PURBA MEDINIPUR  9734282057
# 4                                BAHARGRAM, PANSKURA  9734282057
#
#    diabetesduration  familyhistory  heartdisease  kidneydisease  height  ...  \
# 0                 2              1             0              0     183  ...
# 1                 5              1             0              0     130  ...
# 2                 1              0             1              1     110  ...
# ...

# %%
print(df['phone'].unique())
print(df['diabetesduration'].unique())
# Out:
# [9734282057 8617623168]
# [2 5 1 4]

# %%
excel_path = 'data2.csv'
df2 = pd.read_csv(excel_path)
df2.head()
# Out:
#    Transaction ID  Application ID Description                  Date  Amount
# 0            3004       100000004     Deposit  14-06-2020, at 13:01     500
# 1            3005       100000004    Withdraw  14-06-2020, at 15:03     100
# 2            3007       100000004     Deposit  14-06-2020, at 15:41     500
# 3            3009       100000004    Withdraw  14-06-2020, at 19:54     100
# 4            3010       100000004    Withdraw  14-06-2020, at 19:54     400

# %%
print(df2['Description'].unique())
# Out:
# ['Deposit' 'Withdraw']

# %%
df3 = df2[df2['Amount']>400]
df3.head()
# Out:
#     Transaction ID  Application ID Description                  Date  Amount
# 0             3004       100000004     Deposit  14-06-2020, at 13:01     500
# 2             3007       100000004     Deposit  14-06-2020, at 15:41     500
# 6             3019       100000004     Deposit  23-06-2020, at 18:15    2000
# 10            3027       100000004    Withdraw  09-07-2020, at 10:09     700

# %%
df3.to_csv('new_data.csv')
